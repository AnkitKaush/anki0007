# %%
import pandas as pd
data = pd.read_csv('McDonald Reviews.csv')

# %%
data.head()
# Out:
#    reviewer_id  store_name              category  \
# 0            1  McDonald's  Fast food restaurant
# 1            2  McDonald's  Fast food restaurant
# 2            3  McDonald's  Fast food restaurant
# 3            4  McDonald's  Fast food restaurant
# 4            5  McDonald's  Fast food restaurant
#
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0        1,240  3 months ago
# 1        1,240    5 days ago
# 2        1,240    5 days ago
# 3        1,240   a month ago
# 4        1,240  2 months ago
#
#                                               review   rating
# 0  Why does it look like someone spit on my food?...   1 star
# 1  It'd McDonalds. It is what it is as far as the...  4 stars
# 2  Made a mobile order got to the speaker and che...   1 star
# 3  My mc. Crispy chicken sandwich was customer se...  5 stars
# 4  I repeat my order 3 times in the drive thru, a...   1 star

# %%
corr = data.corr(numeric_only=True)
corr
# Out:
#              reviewer_id  latitude   longitude
# reviewer_id     1.000000  -0.034565  -0.329010
# latitude       -0.034565   1.000000   0.366498
# longitude      -0.329010   0.366498   1.000000

# %%
import matplotlib.pyplot as plt
import warnings
import numpy as np
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import seaborn as sns

corr = data.corr(numeric_only=True)
plt.figure(figsize=(9,10))
sns.heatmap(corr, annot=True ,cmap='coolwarm')
# Out:
# <Axes: >

# %%
data_mapped = data.copy()
data_mapped
# Out:
#       reviewer_id  store_name              category  \
# 0               1  McDonald's  Fast food restaurant
# 1               2  McDonald's  Fast food restaurant
# 2               3  McDonald's  Fast food restaurant
# 3               4  McDonald's  Fast food restaurant
# 4               5  McDonald's  Fast food restaurant
# ...           ...         ...                   ...
# 9995         9996  McDonald's  Fast food restaurant
# 9996         9997  McDonald's  Fast food restaurant
# 9997         9998  McDonald's  Fast food restaurant
# 9998         9999  McDonald's  Fast food restaurant
# 9999        10000  McDonald's  Fast food restaurant
#
#                                           store_address  latitude   longitude  \
# 0     13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1     13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2     13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3     13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4     13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# ...                                                 ...        ...        ...
# 9995  1916 M St NW, Washington, DC 20036, United States  38.905456 -77.044235
# 9996  1916 M St NW, Washington, DC 20036, United States  38.905456 -77.044235
# 9997  1916 M St NW, Washington, DC 20036, United States  38.905456 -77.044235
# 9998  1916 M St NW, Washington, DC 20036, United States  38.905456 -77.044235
# 9999  1916 M St NW, Washington, DC 20036, United States  38.905456 -77.044235
#
#      rating_count   review_time  \
# 0           1,240  3 months ago
# 1           1,240    5 days ago
# 2           1,240    5 days ago
# 3           1,240   a month ago
# 4           1,240  2 months ago
# ...           ...           ...
# 9995        1,269   4 years ago
# 9996        1,269   3 years ago
# 9997        1,269   3 years ago
# 9998        1,269   5 years ago
# 9999        1,269   6 years ago
#
#                                                  review   rating
# 0     Why does it look like someone spit on my food?...   1 star
# 1     It'd McDonalds. It is what it is as far as the...  4 stars
# 2     Made a mobile order got to the speaker and che...   1 star
# 3     My mc. Crispy chicken sandwich was customer se...  5 stars
# 4     I repeat my order 3 times in the drive thru, a...   1 star
# ...                                                 ...      ...
# 9995                                               Good  4 stars
# 9996                                          Excellent  5 stars
# 9997                                           Terrible   1 star
# 9998                                            Neutral  3 stars
# 9999                                            Neutral  3 stars
#
# [10000 rows x 10 columns]

# %%
x = data_mapped.iloc[:,3:4]
x
# Out:
#                                           store_address
# 0     13749 US-183 Hwy, Austin, TX 78750, United States
# 1     13749 US-183 Hwy, Austin, TX 78750, United States
# 2     13749 US-183 Hwy, Austin, TX 78750, United States
# 3     13749 US-183 Hwy, Austin, TX 78750, United States
# 4     13749 US-183 Hwy, Austin, TX 78750, United States
# ...                                                 ...
# 9995  1916 M St NW, Washington, DC 20036, United States
# 9996  1916 M St NW, Washington, DC 20036, United States
# 9997  1916 M St NW, Washington, DC 20036, United States
# 9998  1916 M St NW, Washington, DC 20036, United States
# 9999  1916 M St NW, Washington, DC 20036, United States
#
# [10000 rows x 1 columns]
